# %%
seq = '''...
...'''

# %%
def mismatch(seq):
    string = seq.split('\n')
    first, second = string
    count = 0
    for i in range(len(first)):
        if first[i] != second[i]:
            count += 1
            
    return count

# %%
mismatch(seq)
# Out:
# 462
