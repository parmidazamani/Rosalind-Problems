# %%
strings = '''...
...'''

# %%
string = strings.split('\n')

# %%
first, second = string

# %%
def mismatch(first, second):
    count = 0
    for i in range(len(first)):
        if first[i] != second[i]:
            count += 1
            
    return count

# %%
mismatch(first, second)
# Out:
# 462
